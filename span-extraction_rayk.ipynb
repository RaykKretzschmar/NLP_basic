# %%
import spacy
from spacy.tokens import Doc
from spacy.matcher import Matcher
from zipfile import ZipFile
from pathlib import Path
from seqeval import scheme
from tqdm import autonotebook as tqdm

import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

import sklearn_crfsuite
from collections import Counter

# %%
nlp = spacy.load("en_core_web_sm")

# %%
data_dir = Path("./data/teaching-dataset")
with (data_dir / "span_extraction_text_train.zip").open("rb") as file:
    zip_file = ZipFile(file)
    with zip_file.open("input.txt") as f:
        sentences = [
            sentence.split("\n") for sentence in f.read().decode("utf-8").split("\n\n")
        ]
with (data_dir / "span_extraction_references_train.zip").open("rb") as file:
    zip_file = ZipFile(file)
    with zip_file.open("references.txt") as f:
        labels = [
            sentence.split("\n") for sentence in f.read().decode("utf-8").split("\n\n")
        ]

# %%
# idx = 0
# sentence = sentences[idx]
# doc = Doc(nlp.vocab, words=sentence)
# doc = nlp(doc)
# iterator = zip(doc, labels[idx])
# for token, label in iterator:
#     print(f"{token.text :<16} {label :<8} {token.pos_ :<8} {token.dep_ :<8}")

sentence_number=[]
words=[]
tags=[]
dependencies=[]
events=[]
for i in range(len(sentences)):
    doc = Doc(nlp.vocab, words=sentences[i])
    doc = nlp(doc)
    iterator = zip(doc, labels[i])
    for token, label in iterator:
        sentence_number.append(f'Sentence: {i}')
        words.append(str(token))
        tags.append(token.pos_)
        dependencies.append(token.dep_)
        events.append(label)

train_data = {'Sentence #': sentence_number,'Word': words, 'POS': tags, 'DEP': dependencies, 'Tag': events}
df = pd.DataFrame(data=train_data)
print(df)
# Out:
#           Sentence #       Word    POS     DEP      Tag
# 0        Sentence: 0  According   VERB    prep        O
# 1        Sentence: 0        two    NUM  nummod        O
# 2        Sentence: 0  different    ADJ    amod        O
# 3        Sentence: 0    studies   NOUN    pobj        O
# 4        Sentence: 0         it   PRON   nsubj        O
# ...              ...        ...    ...     ...      ...
# 13425  Sentence: 467         of    ADP    prep        O
# 13426  Sentence: 467      death   NOUN    pobj  B-EVENT
# 13427  Sentence: 467        for    ADP    prep        O
# 13428  Sentence: 467   Haitians  PROPN    pobj        O
# 13429  Sentence: 467          .  PUNCT   punct        O
#
# [13430 rows x 5 columns]

# %%
df.isnull().sum()

df = df.fillna(method='ffill')
df['Sentence #'].nunique(), df.Word.nunique(), df.Tag.nunique()

df.groupby('Tag').size().reset_index(name='counts')

X = df.drop('Tag', axis=1)
v = DictVectorizer(sparse=False)
X = v.fit_transform(X.to_dict('records'))
y = df.Tag.values
classes = np.unique(y)
classes = classes.tolist()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)
X_train.shape, y_train.shape
# Out:
# ((10744, 4012), (10744,))

# %%
per = Perceptron(verbose=10, n_jobs=-1, max_iter=5)
per.partial_fit(X_train, y_train, classes)
# Out:
# -- Epoch 1
# -- Epoch 1
# -- Epoch 1
# Norm: 49.92, NNZs: 1467, Bias: -2.000000, T: 10744, Avg. loss: 0.290581
# Total training time: 0.09 seconds.
# Norm: 69.91, NNZs: 2024, Bias: 3.000000, T: 10744, Avg. loss: 0.573250
# Total training time: 0.09 seconds.
# Norm: 64.36, NNZs: 1841, Bias: -2.000000, T: 10744, Avg. loss: 0.557241
# Total training time: 0.09 seconds.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s finished
# Perceptron(max_iter=5, n_jobs=-1, verbose=10)

# %%
new_classes = classes.copy()
print(new_classes)
# Out:
# ['B-EVENT', 'I-EVENT', 'O']

# %%
print(classification_report(y_pred=per.predict(X_test), y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#      B-EVENT       0.32      0.62      0.42       270
#      I-EVENT       0.52      0.39      0.45       590
#            O       0.86      0.81      0.83      1826
#
#     accuracy                           0.70      2686
#    macro avg       0.57      0.61      0.57      2686
# weighted avg       0.73      0.70      0.71      2686

# %%
sgd = SGDClassifier()
sgd.partial_fit(X_train, y_train, classes)
# Out:
# SGDClassifier()

# %%
print(classification_report(y_pred=sgd.predict(X_test), y_true=y_test, labels=new_classes))
# Out:
#               precision    recall  f1-score   support
#
#      B-EVENT       0.34      0.60      0.43       270
#      I-EVENT       0.45      0.53      0.49       590
#            O       0.89      0.74      0.81      1826
#
#     accuracy                           0.68      2686
#    macro avg       0.56      0.62      0.58      2686
# weighted avg       0.74      0.68      0.70      2686

# %%
nb = MultinomialNB(alpha=0.01)
nb.partial_fit(X_train, y_train, classes)
# Out:
# MultinomialNB(alpha=0.01)

# %%
print(classification_report(y_pred=nb.predict(X_test), y_true=y_test, labels = new_classes))
# Out:
#               precision    recall  f1-score   support
#
#      B-EVENT       0.33      0.61      0.43       270
#      I-EVENT       0.46      0.37      0.41       590
#            O       0.85      0.80      0.82      1826
#
#     accuracy                           0.69      2686
#    macro avg       0.55      0.59      0.55      2686
# weighted avg       0.71      0.69      0.69      2686

# %%
pa =PassiveAggressiveClassifier()
pa.partial_fit(X_train, y_train, classes)
# Out:
# PassiveAggressiveClassifier()

# %%
print(classification_report(y_pred=pa.predict(X_test), y_true=y_test, labels=new_classes))
# Out:
#               precision    recall  f1-score   support
#
#      B-EVENT       0.33      0.33      0.33       270
#      I-EVENT       0.54      0.38      0.45       590
#            O       0.81      0.89      0.85      1826
#
#     accuracy                           0.72      2686
#    macro avg       0.56      0.53      0.54      2686
# weighted avg       0.70      0.72      0.71      2686

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, d, t) for w, p, d, t in zip(s['Word'].values.tolist(), 
                                                           s['POS'].values.tolist(), 
                                                           s['DEP'].values.tolist(),
                                                           s['Tag'].values.tolist())]
        self.grouped = self.data.groupby('Sentence #').apply(agg_func)
        self.sentences = [s for s in self.grouped]
        
    def get_next(self):
        try: 
            s = self.grouped['Sentence: {}'.format(self.n_sent)]
            self.n_sent += 1
            return s 
        except:
            return None
getter = SentenceGetter(df)
sentences = getter.sentences

# %%
print(sentences)
# Out:
# [[('According', 'VERB', 'prep', 'O'), ('two', 'NUM', 'nummod', 'O'), ('different', 'ADJ', 'amod', 'O'), ('studies', 'NOUN', 'pobj', 'O'), ('it', 'PRON', 'nsubj', 'O'), ('seems', 'VERB', 'ROOT', 'O'), ('plausible', 'ADJ', 'oprd', 'O'), ('that', 'SCONJ', 'mark', 'O'), ('the', 'DET', 'det', 'O'), ('Pohang', 'PROPN', 'compound', 'B-EVENT'), ('earthquake', 'NOUN', 'nsubjpass', 'I-EVENT'), ('was', 'AUX', 'auxpass', 'O'), ('induced', 'VERB', 'ccomp', 'O'), ('by', 'ADP', 'agent', 'O'), ('EGS', 'PROPN', 'compound', 'B-EVENT'), ('operations', 'NOUN', 'pobj', 'I-EVENT'), ('.', 'PUNCT', 'punct', 'O')], [('Signs', 'NOUN', 'nsubj', 'O'), ('and', 'CCONJ', 'cc', 'O'), ('symptoms', 'NOUN', 'conj', 'O'), ('include', 'VERB', 'ROOT', 'O'), (':', 'PUNCT', 'punct', 'O'), ('Dyspnea', 'PROPN', 'nsubj', 'O'), ('(', 'PUNCT', 'punct', 'O'), ('shortness', 'NOUN', 'appos', 'O'), ('of', 'ADP', 'prep', 'O'), ('breath', 'NOUN', 'pobj', 'O'), (')', 'PUNCT', 'punct', 'O'), ('exacerbated', 'VERB', 'ccomp', 'O'), ('by', 'ADP', 'agent', 'O'), ('exertion', 'NOUN', 'compound', 'O'), ('Cough', 'PROPN', 'pobj', 'O'), (',', 'PUNCT', 'punct', 'O'), ('often', 'ADV', 'advmod', 'O'), ('persistent', 'ADJ', 'amod', 'O'), ('and', 'CCONJ', 'cc', 'O'), ('sometimes', 'ADV', 'advmod', 'O'), ('severe', 'ADJ', 'conj', 'O'), ('Fatigue', 'PROPN', 'compound', 'O'), ('Tachypnea', 'PROPN', 'conj', 'O'), ('(', 'PUNCT', 'punct', 'O'), ('rapid', 'ADJ', 'amod', 'O'), ('breathing', 'NOUN', 'appos', 'O'), (')', 'PUNCT', 'punct', 'O'), ('which', 'PRON', 'nsubjpass', 'O'), ('is', 'AUX', 'auxpass', 'O'), ('often', 'ADV', 'advmod', 'O'), ('labored', 'VERB', 'relcl', 'O'), (',', 'PUNCT', 'punct', 'O'), ('Loss', 'PROPN', 'nmod', 'O'), ('of', 'ADP', 'prep', 'O'), ('appetite', 'NOUN', 'pobj', 'O'), ('and', 'CCONJ', 'cc', 'O'), ('weight', 'NOUN', 'compound', 'O'), ('loss', 'NOUN', 'conj', 'O'), ('Chest', 'PROPN', 'compound', 'O'), ('pain', 'NOUN', 'compound', 'O'), ('Fever', 'NOUN', 'nmod', 'O'), ('Gradual', 'ADJ', 'amod', 'O'), ('darkening', 'NOUN', 'dobj', 'O'), ('of', 'ADP', 'prep', 'O'), ('skin', 'NOUN', 'pobj', 'O'), ('(', 'PUNCT', 'punct', 'O'), ('blue', 'ADJ', 'amod', 'O'), ('skin', 'NOUN', 'appos', 'O'), (')', 'PUNCT', 'punct', 'O'), ('Gradual', 'ADJ', 'amod', 'B-EVENT'), ('dark', 'ADJ', 'amod', 'I-EVENT'), ('shallow', 'ADJ', 'amod', 'I-EVENT'), ('rifts', 'NOUN', 'nsubj', 'I-EVENT'), ('in', 'ADP', 'prep', 'I-EVENT'), ('nails', 'NOUN', 'pobj', 'I-EVENT'), ('eventually', 'ADV', 'advmod', 'O'), ('leading', 'VERB', 'ROOT', 'O'), ('to', 'ADP', 'prep', 'O'), ('cracks', 'NOUN', 'pobj', 'B-EVENT'), ('as', 'SCONJ', 'mark', 'O'), ('protein', 'NOUN', 'compound', 'O'), ('fibers', 'NOUN', 'nsubjpass', 'O'), ('within', 'ADP', 'prep', 'O'), ('nail', 'NOUN', 'compound', 'O'), ('beds', 'NOUN', 'pobj', 'O'), ('are', 'AUX', 'auxpass', 'O'), ('destroyed', 'VERB', 'advcl', 'O'), ('.', 'PUNCT', 'punct', 'O')], [('Therefore', 'ADV', 'advmod', 'O'), (',', 'PUNCT', 'punct', 'O'), ('the', 'DET', 'det', 'O'), ('neuronal', 'ADJ', 'amod', 'B-EVENT'), ('degeneration', 'NOUN', 'nsubj', 'I-EVENT'), ('in', 'ADP', 'prep', 'I-EVENT'), ('HSAN', 'PROPN', 'compound', 'I-EVENT'), ('IA', 'PROPN', 'pobj', 'I-EVENT'), ('is', 'AUX', 'ROOT', 'O'), ('likely', 'ADJ', 'acomp', 'O'), ('due', 'ADJ', 'prep', 'O'), ('to', 'ADP', 'pcomp', 'O'), ('subtler', 'NOUN', 'nmod', 'B-EVENT'), ('and', 'CCONJ', 'cc', 'I-EVENT'), ('rather', 'ADV', 'advmod', 'I-EVENT'), ('long', 'ADJ', 'amod', 'I-EVENT'), ('-', 'PUNCT', 'punct', 'I-EVENT'), ('term', 'NOUN', 'conj', 'I-EVENT'), ('effects', 'NOUN', 'pobj', 'I-EVENT'), ('of', 'ADP', 'prep', 'I-EVENT'), ('the', 'DET', 'det', 'I-EVENT'), ('mutations', 'NOUN', 'pobj', 'I-EVENT'), ('or', 'CCONJ', 'cc', 'O'), ('perhaps', 'ADV', 'advmod', 'O'), ('accumulation', 'NOUN', 'conj', 'B-EVENT'), ('of', 'ADP', 'prep', 'I-EVENT'), ('toxic', 'ADJ', 'amod', 'I-EVENT'), ('lipids', 'NOUN', 'pobj', 'I-EVENT'), ('produced', 'VERB', 'acl', 'I-EVENT'), ('by', 'ADP', 'agent', 'I-EVENT'), ('mutant', 'ADJ', 'amod', 'I-EVENT'), ('enzym ...

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    deptag = sent[i][2]
    
    features = {
        'bias': 1.0, 
        'word.lower()': word.lower(), 
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
        'deptag': deptag,
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        deptag1 = sent[i-1][2]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
            '-1:deptag': deptag1,
        })
    else:
        features['BOS'] = True
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        deptag1 = sent[i+1][2]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
            '+1:deptag': deptag1,
        })
    else:
        features['EOS'] = True
    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]
def sent2labels(sent):
    return [label for token, postag, deptag, label in sent]
def sent2tokens(sent):
    return [token for token, postag, deptag, label in sent]

# %%
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01, random_state=0)

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
crf.fit(X_train, y_train);

# %%
def flatten(l):
    output = []
    for sublist in l:
        for item in sublist:
            output.append(item)

        output.append('')
    return output

y_pred = crf.predict(X_test)
# print(metrics.flat_classification_report(y_pred=y_pred, y_true=y_test, labels = new_classes))
# sollte eigentlich funktionieren tuts aber nicht
flat_y_true = flatten(y_test)
flat_y_pred = flatten(y_pred)
print(classification_report(flat_y_true, flat_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#                    1.00      1.00      1.00         5
#      B-EVENT       0.73      0.50      0.59        16
#      I-EVENT       0.59      0.59      0.59        32
#            O       0.80      0.84      0.82        83
#
#     accuracy                           0.75       136
#    macro avg       0.78      0.73      0.75       136
# weighted avg       0.75      0.75      0.75       136

# %%
data_dir = Path("./data/teaching-dataset")
with (data_dir / "span_extraction_text_test.zip").open("rb") as file:
    zip_file = ZipFile(file)
    with zip_file.open("input.txt") as f:
        test_sentences = [
            sentence.split("\n") for sentence in f.read().decode("utf-8").split("\n\n")
        ]

print(len(test_sentences))
# Out:
# 98

# %%
sentence_number=[]
words=[]
tags=[]
dependencies=[]
events=[]
for i in range(len(test_sentences)):
    doc = Doc(nlp.vocab, words=test_sentences[i])
    doc = nlp(doc)
    for token in doc:
        sentence_number.append(f'Sentence: {i}')
        words.append(str(token))
        tags.append(token.pos_)
        dependencies.append(token.dep_)

train_data = {'Sentence #': sentence_number,'Word': words, 'POS': tags, 'DEP': dependencies}
df = pd.DataFrame(data=train_data)
print(df)
# Out:
#         Sentence #               Word    POS       DEP
# 0      Sentence: 0              After    ADP      prep
# 1      Sentence: 0                the    DET       det
# 2      Sentence: 0            Trinity  PROPN  compound
# 3      Sentence: 0               test   NOUN      pobj
# 4      Sentence: 0                  ,  PUNCT     punct
# ...            ...                ...    ...       ...
# 2849  Sentence: 97         inhibitory    ADJ      amod
# 2850  Sentence: 97  neurotransmitters   NOUN      pobj
# 2851  Sentence: 97               like    ADP      prep
# 2852  Sentence: 97               GABA  PROPN      pobj
# 2853  Sentence: 97                  .  PUNCT     punct
#
# [2854 rows x 4 columns]

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, d) for w, p, d in zip(s['Word'].values.tolist(), 
                                                           s['POS'].values.tolist(), 
                                                           s['DEP'].values.tolist())]
        self.grouped = self.data.groupby('Sentence #').apply(agg_func)
        

        print(self.grouped.head(20))
        self.sentences = [s for s in self.grouped]
        
        
    def get_next(self):
        try: 
            s = self.grouped['Sentence: {}'.format(self.n_sent)]
            self.n_sent += 1
            return s 
        except:
            return None
getter = SentenceGetter(df)
sentences = getter.sentences
for sentence in sentences:
    print(sentence)
# print(sentences)
# Out:
# Sentence #
# 0     [(After, ADP, prep), (the, DET, det), (Trinity...
# 1     [(Arteriovenous, ADJ, amod), (fistula, NOUN, n...
# 2     [(A, DET, det), (study, NOUN, nsubj), (by, ADP...
# 3     [(Dietary, ADJ, nsubj), (causes, VERB, ROOT), ...
# 4     [(On, ADP, prep), (November, PROPN, pobj), (20...
# 5     [(A, DET, det), (study, NOUN, nsubj), (done, V...
# 6     [(Phytophthora, NOUN, ROOT), (a, DET, det), (g...
# 7     [(Pain, NOUN, nsubjpass), (associated, VERB, a...
# 8     [(During, ADP, prep), (underground, ADJ, amod)...
# 9     [(Discrediting, VERB, advcl), (earlier, ADJ, a...
# 10    [(During, ADP, prep), (the, DET, det), (1970s,...
# 11    [(Late, ADJ, amod), (-, PUNCT, punct), (phase,...
# 12    [(The, DET, det), (2008, NUM, nummod), (Sichua...
# 13    [(With, ADP, prep), (interventional, ADJ, amod...
# 14    [(People, NOUN, nsubj), (who, PRON, nsubj), (h...
# 15    [(Mutations, NOUN, nsubj), (in, ADP, prep), (t...
# 16    [(The, DET, det), (undigested, ADJ, amod), (fa...
# 17    [(Political, ADJ, amod), (instability, NOUN, n...
# 18    [(Very, ADV, advmod), (rarely, ADV, advmod), (...
# 19    [(Acquired, PROPN, amod), (thrombocytopenia, N...
# dtype: object
# [('After', 'ADP', 'prep'), ('the', 'DET', 'det'), ('Trinity', 'PROPN', 'compound'), ('test', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('the', 'DET', 'det'), ('fallout', 'NOUN', 'nsubj'), ('caused', 'VERB', 'ROOT'), ('localized', 'VERB', 'amod'), ('burns', 'NOUN', 'dobj'), ('on', 'ADP', 'prep'), ('the', 'DET', 'det'), ('backs', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('cattle', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('area', 'NOUN', 'pobj'), ('downwind', 'ADV', 'advmod'), ('.', 'PUNCT', 'punct')]
# [('Arteriovenous', 'ADJ', 'amod'), ('fistula', 'NOUN', 'nsubj'), ('(', 'PUNCT', 'punct'), ('an', 'DET', 'det'), ('abnormal', 'ADJ', 'amod'), ('connection', 'NOUN', 'appos'), ('or', 'CCONJ', 'cc'), ('passageway', 'NOUN', 'conj'), ('between', 'ADP', 'prep'), ('an', 'DET', 'det'), ('artery', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('a', 'DET', 'det'), ('vein', 'NOUN', 'conj'), (')', 'PUNCT', 'punct'), ('may', 'AUX', 'aux'), ('cause', 'VERB', 'ROOT'), ('chronic', 'ADJ', 'amod'), ('venous', 'ADJ', 'amod'), ('insufficiency', 'NOUN', 'dobj'), ('even', 'ADV', 'advmod'), ('with', 'ADP', 'prep'), ('working', 'VERB', 'amod'), ('vein', 'NOUN', 'compound'), ('valves', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('A', 'DET', 'det'), ('study', 'NOUN', 'nsubj'), ('by', 'ADP', 'prep'), ('Houston', 'PROPN', 'pobj'), ('and', 'CCONJ', 'cc'), ('colleagues', 'NOUN', 'conj'), ('showed', 'VERB', 'ROOT'), ('how', 'SCONJ', 'advmod'), ('decreased', 'VERB', 'amod'), ('protein', 'NOUN', 'compound'), ('intake', 'NOUN', 'nsubj'), ('may', 'AUX', 'aux'), ('increase', 'VERB', 'ccomp'), ('the', 'DET', 'det'), ('risk', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('developing', 'VERB', 'pcomp'), ('mobility', 'NOUN', 'compound'), ('limitations', 'NOUN', 'dobj'), ('later', 'ADV', 'advmod'), ('on', 'ADV', 'advmod'), ('.', 'PUNCT', 'punct')]
# [('Dietary', 'ADJ', 'nsubj'), ('causes', 'VERB', 'ROOT'), ('account', 'NOUN', 'dobj'), ('for', 'ADP', 'prep'), ('about', 'ADV', 'advmod'), ('12', 'NUM', 'nummod'), ('%', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('gout', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('include', 'VERB', 'conj'), ('a', 'DET', 'det'), ('strong', 'ADJ', 'amod'), ('association', 'NOUN', 'dobj'), ('with', 'ADP', 'prep'), ('the', 'DET', 'det'), ('consumption', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('alcohol', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('fructose', 'ADV', 'npadvmod'), ('-', 'PUNCT', 'punct'), ('sweetened', 'VERB', 'amod'), ('drinks', 'NOUN', 'conj'), (',', 'PUNCT', 'punct'), ('meat', 'NOUN', 'conj'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('seafood', 'NOUN', 'conj'), ('.', 'PUNCT', 'punct')]
# [('On', 'ADP', 'prep'), ('November', 'PROPN', 'pobj'), ('2017', 'NUM', 'nummod'), ('a', 'PRON', 'mark'), ('Mw', 'PROPN', 'nsubj'), ('5.5', 'NUM', 'nummod'), ('struck', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('city', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('Pohang', 'PROPN', 'pobj'), ('(', 'PUNCT', 'punct'), ('South', 'PROPN', 'compound'), ('Korea', 'PROPN', 'appos'), (')', 'PUNCT', 'punct'), ('injuring', 'VERB', 'advcl'), ('several', 'ADJ', 'amod'), ('people', 'NOUN', 'dobj'), ('and', 'CCONJ', 'cc'), ('causing', 'VERB', 'conj'), ('extensive', 'ADJ', 'amod'), ('damage', 'NOUN', 'dobj'), (',', 'PUNCT', 'punct'), ('the', 'DET', 'det'), ('proximity', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('seismic', 'ADJ', 'amod'), ('sequence', 'NOUN', 'pobj'), ('with', 'ADP', 'prep'), ('an', 'DET', 'det'), ('EGS', 'PROPN', 'compound'), ('site', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('where', 'SCONJ', 'advmod'), ('stimulation', 'NOUN', 'compound'), ('operations', 'NOUN', 'nsubj'), ('has', 'AUX', 'aux'), ('taken', 'VERB', 'relcl'), ('place', 'NOUN', 'dobj'), ('few', 'ADJ', 'amod'), ('months', 'NOUN', 'npadvmod'), ('prior', 'ADV', 'advmod'), ('the', 'DET', 'det'), ('earthquake', 'NOUN', 'nsubj'), ('raised', 'VERB', 'conj'), ('the', 'DET', 'det'), ('possibility', 'NOUN', 'dobj'), ('that', 'PRON', 'nsubj'), ('raises', 'VERB', 'relcl'), ('the', 'DET', 'det'), ('possibility', 'NOUN', 'dobj'), ('that', 'SCONJ', 'mark'), ('this', 'DET', 'det'), ('earthquake', 'NOUN', 'nsubj'), ('was', 'AUX', 'acl'), ('anthropogenic', 'ADJ', 'acomp'), ('.', 'PUNCT', 'punct')]
# [('A', 'DET', 'det'), ('study', 'NOUN', 'nsubj'), ('done', 'VERB', 'acl'), ('by', 'ADP', 'agent'), ('Jatturong', 'PROPN', 'compound'), ('R.', 'PROPN', 'compound'), ('Wichianson', 'PROPN', 'pobj'), ('and', 'CCONJ', 'cc'), ('colleagues', 'NOUN', 'conj'), ('at', 'ADP', 'prep'), ('the', 'DET', 'det'), ('University', 'PROPN', 'pobj'), ('of', 'ADP', 'prep'), ('Southern', 'PROPN', 'compound'), ('California', 'PROPN', 'pobj'), ('showed', 'VERB', 'ROOT'), ('a', 'DET', 'det'), ('direct', 'ADJ', 'amod'), ('relationship', 'NOUN', 'dobj'), ('between', 'ADP', 'prep'), ('eating', 'VERB', 'pcomp'), ('late', 'ADV', 'advmod'), ('at', 'ADP', 'prep'), ('night', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('Night', 'PROPN', 'compound'), ('eating', 'VERB', 'amod'), ('syndrome', 'NOUN', 'parataxis'), (')', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('stress', 'NOUN', 'compound'), ('levels', 'NOUN', 'conj'), ('with', 'ADP', 'prep'), ('college', 'NOUN', 'compound'), ('students', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Phytophthora', 'NOUN', 'ROOT'), ('a', 'DET', 'det'), ('genus', 'NOUN', 'appos'), ('of', 'ADP', 'prep'), ('plant', 'NOUN', 'npadvmod'), ('-', 'PUNCT', 'punct'), ('damaging', 'VERB', 'amod'), ('oomycetes', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('water', 'NOUN', 'compound'), ('molds', 'NOUN', 'appos'), (')', 'PUNCT', 'punct'), (',', 'PUNCT', 'punct'), ('whose', 'DET', 'poss'), ('member', 'NOUN', 'compound'), ('species', 'NOUN', 'nsubj'), ('are', 'AUX', 'relcl'), ('capable', 'ADJ', 'acomp'), ('of', 'ADP', 'prep'), ('causing', 'VERB', 'pcomp'), ('enormous', 'ADJ', 'amod'), ('economic', 'ADJ', 'amod'), ('losses', 'NOUN', 'dobj'), ('on', 'ADP', 'prep'), ('crops', 'NOUN', 'pobj'), ('worldwide', 'ADV', 'advmod'), (',', 'PUNCT', 'punct'), ('as', 'ADV', 'advmod'), ('well', 'ADV', 'advmod'), ('as', 'ADP', 'cc'), ('environmental', 'ADJ', 'amod'), ('damage', 'NOUN', 'dobj'), ('in', 'ADP', 'prep'), ('natural', 'ADJ', 'amod'), ('ecosystems', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Pain', 'NOUN', 'nsubjpass'), ('associated', 'VERB', 'acl'), ('with', 'ADP', 'prep'), ('facet', 'PROPN', 'compound'), ('syndrome', 'NOUN', 'pobj'), ('is', 'AUX', 'auxpass'), ('often', 'ADV', 'advmod'), ('called', 'VERB', 'ROOT'), ('"', 'PUNCT', 'punct'), ('referred', 'VERB', 'amod'), ('pain', 'NOUN', 'oprd'), ('"', 'PUNCT', 'punct'), ('because', 'SCONJ', 'mark'), ('symptoms', 'NOUN', 'nsubj'), ('do', 'AUX', 'aux'), ('not', 'PART', 'neg'), ('follow', 'VERB', 'advcl'), ('a', 'DET', 'det'), ('specific', 'ADJ', 'amod'), ('nerve', 'NOUN', 'compound'), ('root', 'NOUN', 'compound'), ('pattern', 'NOUN', 'dobj'), ('and', 'CCONJ', 'cc'), ('the', 'DET', 'det'), ('brain', 'NOUN', 'nsubj'), ('can', 'AUX', 'aux'), ('have', 'VERB', 'conj'), ('difficulty', 'NOUN', 'dobj'), ('localizing', 'VERB', 'acl'), ('the', 'DET', 'det'), ('specific', 'ADJ', 'amod'), ('area', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('spine', 'NOUN', 'pobj'), ('that', 'PRON', 'nsubjpass'), ('is', 'AUX', 'auxpass'), ('affected', 'VERB', 'relcl'), ('.', 'PUNCT', 'punct')]
# [('During', 'ADP', 'prep'), ('underground', 'ADJ', 'amod'), ('nuclear', 'ADJ', 'amod'), ('testing', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('Nevada', 'PROPN', 'pobj'), (',', 'PUNCT', 'punct'), ('several', 'ADJ', 'amod'), ('workers', 'NOUN', 'nsubj'), ('developed', 'VERB', 'ROOT'), ('burns', 'NOUN', 'dobj'), ('and', 'CCONJ', 'cc'), ('skin', 'NOUN', 'compound'), ('ulcers', 'NOUN', 'conj'), (',', 'PUNCT', 'punct'), ('in', 'ADP', 'prep'), ('part', 'NOUN', 'pobj'), ('attributed', 'VERB', 'acl'), ('to', 'ADP', 'prep'), ('exposure', 'NOUN', 'pobj'), ('to', 'ADP', 'prep'), ('tritium', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Discrediting', 'VERB', 'advcl'), ('earlier', 'ADJ', 'amod'), ('notions', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('presbycusis', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('Rosen', 'PROPN', 'nsubj'), ('demonstrated', 'VERB', 'ROOT'), ('that', 'SCONJ', 'mark'), ('long', 'ADJ', 'amod'), ('term', 'NOUN', 'compound'), ('hearing', 'NOUN', 'compound'), ('loss', 'NOUN', 'nsubj'), ('is', 'AUX', 'ccomp'), ('usually', 'ADV', 'advmod'), ('the', 'DET', 'det'), ('product', 'NOUN', 'attr'), ('of', 'ADP', 'prep'), ('chronic', 'ADJ', 'amod'), ('exposure', 'NOUN', 'pobj'), ('to', 'ADP', 'prep'), ('environmental', 'ADJ', 'amod'), ('noise', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('industrialized', 'VERB', 'amod'), ('countries', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('Rosen', 'PROPN', 'appos'), (',', 'PUNCT', 'punct'), ('1965', 'NUM', 'npadvmod'), (')', 'PUNCT', 'punct'), ('.', 'PUNCT', 'punct')]
# [('During', 'ADP', 'prep'), ('the', 'DET', 'det'), ('1970s', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('1980s', 'NOUN', 'conj'), (',', 'PUNCT', 'punct'), ('when', 'SCONJ', 'advmod'), ('an', 'DET', 'det'), ('outbreak', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('this', 'DET', 'det'), ('syndrome', 'NOUN', 'pobj'), ('began', 'VERB', 'advcl'), (',', 'PUNCT', 'punct'), ('many', 'ADJ', 'nsubj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('Southeast', 'PROPN', 'compound'), ('Asians', 'PROPN', 'pobj'), ('were', 'AUX', 'ROOT'), ('not', 'PART', 'neg'), ('able', 'ADJ', 'acomp'), ('to', 'PART', 'aux'), ('worship', 'VERB', 'xcomp'), ('properly', 'ADV', 'advmod'), ('due', 'ADP', 'prep'), ('to', 'ADP', 'pcomp'), ('the', 'DET', 'det'), ('guerrilla', 'NOUN', 'compound'), ('war', 'NOUN', 'pobj'), ('against', 'ADP', 'prep'), ('the', 'DET', 'det'), ('government', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('Laos', 'PROPN', 'pobj'), ('with', 'ADP', 'prep'), ('the', 'DET', 'det'), ('United', 'PROPN', 'compound'), ('States', 'PROPN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Late', 'ADJ', 'amod'), ('-', 'PUNCT', 'punct'), ('phase', 'NOUN', 'compound'), ('responses', 'NOUN', 'nsubj'), ('seen', 'VERB', 'acl'), ('in', 'ADP', 'prep'), ('asthma', 'NOUN', 'pobj'), ('are', 'AUX', 'ROOT'), ('slightly', 'ADV', 'advmod'), ('different', 'ADJ', 'acomp'), ('from', 'ADP', 'prep'), ('those', 'PRON', 'pobj'), ('seen', 'VERB', 'acl'), ('in', 'ADP', 'prep'), ('other', 'ADJ', 'amod'), ('allergic', 'ADJ', 'amod'), ('responses', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('although', 'SCONJ', 'mark'), ('they', 'PRON', 'nsubjpass'), ('are', 'AUX', 'auxpass'), ('still', 'ADV', 'advmod'), ('caused', 'VERB', 'advcl'), ('by', 'ADP', 'agent'), ('release', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('mediators', 'NOUN', 'pobj'), ('from', 'ADP', 'prep'), ('eosinophils', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('2008', 'NUM', 'nummod'), ('Sichuan', 'PROPN', 'compound'), ('earthquake', 'NOUN', 'nsubj'), (',', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubj'), ('caused', 'VERB', 'relcl'), ('approximately', 'ADV', 'advmod'), ('68,000', 'NUM', 'nummod'), ('deaths', 'NOUN', 'dobj'), (',', 'PUNCT', 'punct'), ('is', 'AUX', 'ROOT'), ('another', 'DET', 'det'), ('possible', 'ADJ', 'amod'), ('example', 'NOUN', 'attr'), ('.', 'PUNCT', 'punct')]
# [('With', 'ADP', 'prep'), ('interventional', 'ADJ', 'amod'), ('fluoroscopy', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('because', 'SCONJ', 'prep'), ('of', 'ADP', 'pcomp'), ('the', 'DET', 'det'), ('high', 'ADJ', 'amod'), ('skin', 'NOUN', 'compound'), ('doses', 'NOUN', 'pobj'), ('that', 'PRON', 'nsubjpass'), ('can', 'AUX', 'aux'), ('be', 'AUX', 'auxpass'), ('generated', 'VERB', 'relcl'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('course', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('intervention', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('some', 'DET', 'det'), ('procedures', 'NOUN', 'nsubj'), ('have', 'AUX', 'aux'), ('resulted', 'VERB', 'ROOT'), ('in', 'ADP', 'prep'), ('early', 'ADJ', 'pcomp'), ('(', 'PUNCT', 'punct'), ('less', 'ADJ', 'amod'), ('than', 'ADP', 'quantmod'), ('two', 'NUM', 'nummod'), ('months', 'NOUN', 'npadvmod'), ('after', 'ADP', 'prep'), ('exposure', 'NOUN', 'pobj'), (')', 'PUNCT', 'punct'), ('and/or', 'CCONJ', 'cc'), ('late', 'ADJ', 'amod'), ('(', 'PUNCT', 'punct'), ('two', 'NUM', 'nummod'), ('months', 'NOUN', 'npadvmod'), ('or', 'CCONJ', 'cc'), ('more', 'ADJ', 'nummod'), ('after', 'ADP', 'prep'), ('exposure', 'NOUN', 'pobj'), (')', 'PUNCT', 'punct'), ('skin', 'NOUN', 'compound'), ('reactions', 'NOUN', 'dobj'), (',', 'PUNCT', 'punct'), ('including', 'VERB', 'prep'), ('necrosis', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('some', 'DET', 'det'), ('cases', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('People', 'NOUN', 'nsubj'), ('who', 'PRON', 'nsubj'), ('have', 'VERB', 'relcl'), ('these', 'DET', 'det'), ('mutations', 'NOUN', 'dobj'), ('are', 'AUX', 'ROOT'), ('also', 'ADV', 'advmod'), ('at', 'ADP', 'prep'), ('an', 'DET', 'det'), ('increased', 'VERB', 'amod'), ('risk', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('developing', 'VERB', 'pcomp'), ('porphyria', 'NOUN', 'compound'), ('cutanea', 'PROPN', 'compound'), ('tarda', 'PROPN', 'dobj'), ('.', 'PUNCT', 'punct')]
# [('Mutations', 'NOUN', 'nsubj'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('HMGCL', 'PROPN', 'compound'), ('gene', 'NOUN', 'pobj'), ('cause', 'VERB', 'ROOT'), ('3', 'NUM', 'nummod'), ('-', 'PUNCT', 'punct'), ('hydroxy-3', 'PROPN', 'compound'), ('-', 'PUNCT', 'punct'), ('methylglutaryl', 'PROPN', 'compound'), ('-', 'PUNCT', 'punct'), ('CoA', 'PROPN', 'compound'), ('lyase', 'NOUN', 'compound'), ('deficiency', 'NOUN', 'dobj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('undigested', 'ADJ', 'amod'), ('fat', 'NOUN', 'nsubj'), ('leads', 'VERB', 'ROOT'), ('to', 'ADP', 'prep'), ('foul', 'ADV', 'advmod'), ('-', 'PUNCT', 'punct'), ('smelling', 'VERB', 'amod'), (',', 'PUNCT', 'punct'), ('fatty', 'ADJ', 'compound'), ('feces', 'NOUN', 'pobj'), ('that', 'PRON', 'nsubj'), ('are', 'AUX', 'relcl'), ('difficult', 'ADJ', 'acomp'), ('to', 'PART', 'aux'), ('flush', 'VERB', 'xcomp'), ('away', 'ADV', 'advmod'), ('.', 'PUNCT', 'punct')]
# [('Political', 'ADJ', 'amod'), ('instability', 'NOUN', 'nsubj'), ('and', 'CCONJ', 'cc'), ('corruption', 'NOUN', 'conj'), ('have', 'AUX', 'aux'), ('left', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('country', 'NOUN', 'dobj'), ('with', 'ADP', 'prep'), ('a', 'DET', 'det'), ('number', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('social', 'ADJ', 'amod'), ('problems', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('such', 'ADJ', 'amod'), ('as', 'ADP', 'prep'), ('a', 'DET', 'det'), ('lack', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('access', 'NOUN', 'pobj'), ('to', 'ADP', 'prep'), ('basic', 'ADJ', 'amod'), ('human', 'ADJ', 'amod'), ('rights', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('including', 'VERB', 'prep'), ('education', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('healthcare', 'NOUN', 'conj'), (';', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('an', 'DET', 'det'), ('economy', 'NOUN', 'conj'), ('with', 'ADP', 'prep'), ('a', 'DET', 'det'), ('lower', 'ADJ', 'pobj'), ('than', 'ADP', 'prep'), ('average', 'ADJ', 'amod'), ('domestic', 'ADJ', 'amod'), ('product', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Very', 'ADV', 'advmod'), ('rarely', 'ADV', 'advmod'), (',', 'PUNCT', 'punct'), ('extremely', 'ADV', 'advmod'), ('large', 'ADJ', 'amod'), ('hemangiomas', 'PRON', 'nsubj'), ('can', 'AUX', 'aux'), ('cause', 'VERB', 'ROOT'), ('high', 'ADJ', 'amod'), ('-', 'PUNCT', 'punct'), ('output', 'NOUN', 'compound'), ('heart', 'NOUN', 'compound'), ('failure', 'NOUN', 'dobj'), ('due', 'ADP', 'prep'), ('to', 'ADP', 'pcomp'), ('the', 'DET', 'det'), ('amount', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('blood', 'NOUN', 'pobj'), ('that', 'PRON', 'nsubjpass'), ('must', 'AUX', 'aux'), ('be', 'AUX', 'auxpass'), ('pumped', 'VERB', 'relcl'), ('to', 'ADP', 'prep'), ('excess', 'ADJ', 'amod'), ('blood', 'NOUN', 'compound'), ('vessels', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Acquired', 'PROPN', 'amod'), ('thrombocytopenia', 'NOUN', 'nsubjpass'), ('may', 'AUX', 'aux'), ('be', 'AUX', 'auxpass'), ('associated', 'VERB', 'ROOT'), ('with', 'ADP', 'prep'), ('a', 'DET', 'det'), ('history', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('drug', 'NOUN', 'compound'), ('use', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('blood', 'NOUN', 'compound'), ('hemoglobin', 'NOUN', 'compound'), ('levels', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('these', 'DET', 'det'), ('treated', 'VERB', 'amod'), ('patients', 'NOUN', 'pobj'), ('rose', 'VERB', 'ROOT'), ('as', 'ADP', 'prep'), ('a', 'DET', 'det'), ('result', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('reduced', 'ADJ', 'amod'), ('hemorrhage', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('enhanced', 'VERB', 'amod'), ('blood', 'NOUN', 'compound'), ('vessel', 'NOUN', 'compound'), ('stabilization', 'NOUN', 'conj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('theatrical', 'ADJ', 'amod'), ('trailer', 'NOUN', 'nsubj'), ('caused', 'VERB', 'ROOT'), ('even', 'ADV', 'advmod'), ('more', 'ADJ', 'amod'), ('media', 'NOUN', 'compound'), ('attention', 'NOUN', 'dobj'), ('because', 'SCONJ', 'mark'), ('it', 'PRON', 'nsubjpass'), ('was', 'AUX', 'auxpass'), ('premiered', 'VERB', 'advcl'), ('in', 'ADP', 'prep'), ('theaters', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('screened', 'VERB', 'conj'), ('at', 'ADP', 'prep'), ('the', 'DET', 'det'), ('ShoWest', 'PROPN', 'compound'), ('Convention', 'PROPN', 'pobj'), ('in', 'ADP', 'prep'), ('Las', 'PROPN', 'compound'), ('Vegas', 'PROPN', 'pobj'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('was', 'AUX', 'auxpass'), ('aired', 'VERB', 'conj'), ('on', 'ADP', 'prep'), ('Entertainment', 'PROPN', 'compound'), ('Tonight', 'PROPN', 'pobj'), ('and', 'CCONJ', 'cc'), ('Access', 'PROPN', 'compound'), ('Hollywood', 'PROPN', 'conj'), ('.', 'PUNCT', 'punct')]
# [('These', 'PRON', 'nsubj'), ('can', 'AUX', 'aux'), ('oxidize', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('UROD', 'PROPN', 'amod'), ('substrate', 'NOUN', 'compound'), ('uroporphyrinogen', 'NOUN', 'dobj'), (',', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubj'), ('can', 'AUX', 'aux'), ('result', 'VERB', 'relcl'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('inhibition', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('UROD', 'PROPN', 'pobj'), ('and', 'CCONJ', 'cc'), ('lead', 'VERB', 'conj'), ('to', 'ADP', 'prep'), ('deficient', 'ADJ', 'amod'), ('activity', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('this', 'DET', 'det'), ('key', 'ADJ', 'amod'), ('enzyme', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('In', 'ADP', 'prep'), ('2010', 'NUM', 'pobj'), (',', 'PUNCT', 'punct'), ('Haiti', 'PROPN', 'nsubj'), ('also', 'ADV', 'advmod'), ('experienced', 'VERB', 'ROOT'), ('a', 'DET', 'det'), ('cholera', 'NOUN', 'compound'), ('outbreak', 'NOUN', 'dobj'), ('that', 'PRON', 'nsubj'), ('spread', 'VERB', 'relcl'), ('quickly', 'ADV', 'advmod'), ('throughout', 'ADP', 'prep'), ('the', 'DET', 'det'), ('nation', 'NOUN', 'pobj'), ('due', 'ADP', 'prep'), ('to', 'ADP', 'pcomp'), ('difficulties', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('healthcare', 'NOUN', 'compound'), ('access', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('the', 'DET', 'det'), ('lack', 'NOUN', 'conj'), ('of', 'ADP', 'prep'), ('experience', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('healthcare', 'NOUN', 'compound'), ('system', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('New', 'PROPN', 'compound'), ('Zealand', 'PROPN', 'compound'), ('AA', 'PROPN', 'nsubj'), ('has', 'AUX', 'aux'), ('submitted', 'VERB', 'ROOT'), ('to', 'ADP', 'prep'), ('the', 'DET', 'det'), ('Government', 'PROPN', 'pobj'), ('that', 'SCONJ', 'mark'), ('New', 'PROPN', 'nmod'), ('Zealands', 'PROPN', 'nmod'), ('poor', 'ADJ', 'amod'), ('road', 'NOUN', 'compound'), ('safety', 'NOUN', 'compound'), ('performance', 'NOUN', 'nsubj'), ('is', 'AUX', 'ccomp'), ('due', 'ADJ', 'acomp'), ('to', 'ADP', 'prep'), ('misplaced', 'VERB', 'amod'), ('overemphasis', 'NOUN', 'pobj'), ('on', 'ADP', 'prep'), ('speed', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('alcohol', 'NOUN', 'conj'), ('when', 'SCONJ', 'advmod'), ('emergent', 'ADJ', 'amod'), ('risks', 'NOUN', 'nsubj'), ('are', 'AUX', 'advcl'), ('now', 'ADV', 'advmod'), ('more', 'ADV', 'advmod'), ('significant', 'ADJ', 'acomp'), ('(', 'PUNCT', 'punct'), ('Saving', 'VERB', 'advcl'), ('Ourselves', 'PRON', 'dep'), ('publication', 'NOUN', 'dobj'), (',', 'PUNCT', 'punct'), ('submissions', 'NOUN', 'dep'), ('to', 'ADP', 'prep'), ('2020', 'NUM', 'nummod'), ('plan', 'NOUN', 'compound'), ('consultation', 'NOUN', 'pobj'), (')', 'PUNCT', 'punct'), ('.', 'PUNCT', 'punct')]
# [('Also', 'ADV', 'advmod'), ('much', 'ADJ', 'nsubj'), ('of', 'ADP', 'prep'), ('this', 'PRON', 'pobj'), ('comes', 'VERB', 'ROOT'), ('from', 'ADP', 'prep'), ('the', 'DET', 'det'), ('transition', 'NOUN', 'pobj'), ('from', 'ADP', 'prep'), ('living', 'VERB', 'pcomp'), ('at', 'ADP', 'prep'), ('home', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('to', 'ADP', 'prep'), ('living', 'VERB', 'pcomp'), ('on', 'ADP', 'prep'), ('their', 'PRON', 'poss'), ('own', 'ADJ', 'pobj'), (',', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubj'), ('results', 'VERB', 'advcl'), ('in', 'ADP', 'prep'), ('students', 'NOUN', 'pobj'), ('not', 'PART', 'neg'), ('knowing', 'VERB', 'advcl'), ('how', 'SCONJ', 'advmod'), ('to', 'PART', 'aux'), ('properly', 'ADV', 'advmod'), ('eat', 'VERB', 'xcomp'), ('on', 'ADP', 'prep'), ('their', 'PRON', 'poss'), ('own', 'ADJ', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Patients', 'NOUN', 'nsubj'), ('often', 'ADV', 'advmod'), ('report', 'VERB', 'ROOT'), ('quick', 'ADJ', 'amod'), ('jerking', 'VERB', 'amod'), ('movements', 'NOUN', 'dobj'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('morning', 'NOUN', 'pobj'), ('that', 'PRON', 'nsubj'), ('results', 'VERB', 'relcl'), ('in', 'ADP', 'prep'), ('knocking', 'VERB', 'pcomp'), ('over', 'ADP', 'prt'), ('objects', 'NOUN', 'dobj'), ('around', 'ADP', 'prep'), ('them', 'PRON', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('At', 'ADP', 'prep'), ('high', 'ADJ', 'amod'), ('levels', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('uric', 'ADJ', 'amod'), ('acid', 'NOUN', 'nsubj'), ('crystallizes', 'VERB', 'ROOT'), ('and', 'CCONJ', 'cc'), ('the', 'DET', 'det'), ('crystals', 'NOUN', 'nsubj'), ('deposit', 'VERB', 'conj'), ('in', 'ADP', 'prep'), ('joints', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('tendons', 'NOUN', 'conj'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('surrounding', 'VERB', 'conj'), ('tissues', 'NOUN', 'dobj'), (',', 'PUNCT', 'punct'), ('resulting', 'VERB', 'advcl'), ('in', 'ADP', 'prep'), ('an', 'DET', 'det'), ('attack', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('gout', 'PROPN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('A', 'DET', 'det'), ('2011', 'NUM', 'nummod'), ('study', 'NOUN', 'nsubj'), ('found', 'VERB', 'ROOT'), ('that', 'SCONJ', 'mark'), ('pollution', 'NOUN', 'nsubj'), ('is', 'AUX', 'aux'), ('making', 'VERB', 'ccomp'), ('Arabian', 'PROPN', 'compound'), ('Sea', 'PROPN', 'compound'), ('cyclones', 'NOUN', 'nsubj'), ('more', 'ADV', 'advmod'), ('intense', 'ADJ', 'ccomp'), ('as', 'SCONJ', 'mark'), ('the', 'DET', 'det'), ('atmospheric', 'ADJ', 'amod'), ('brown', 'ADJ', 'amod'), ('clouds', 'NOUN', 'nsubj'), ('has', 'AUX', 'aux'), ('been', 'AUX', 'aux'), ('producing', 'VERB', 'advcl'), ('weakening', 'VERB', 'amod'), ('wind', 'NOUN', 'compound'), ('patterns', 'NOUN', 'dobj'), ('which', 'PRON', 'nsubj'), ('prevent', 'VERB', 'relcl'), ('wind', 'NOUN', 'compound'), ('shear', 'NOUN', 'compound'), ('patterns', 'NOUN', 'dobj'), ('that', 'PRON', 'nsubj'), ('historically', 'ADV', 'advmod'), ('have', 'AUX', 'aux'), ('prohibited', 'VERB', 'relcl'), ('cyclones', 'NOUN', 'dobj'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('Arabian', 'PROPN', 'compound'), ('Sea', 'PROPN', 'pobj'), ('from', 'ADP', 'prep'), ('becoming', 'VERB', 'pcomp'), ('major', 'ADJ', 'amod'), ('storms', 'NOUN', 'attr'), ('.', 'PUNCT', 'punct')]
# [('As', 'ADP', 'prep'), ('a', 'DET', 'det'), ('result', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('continuous', 'ADJ', 'amod'), ('raids', 'NOUN', 'pobj'), ('a', 'DET', 'det'), ('huge', 'ADJ', 'amod'), ('number', 'NOUN', 'nsubjpass'), ('of', 'ADP', 'prep'), ('Russian', 'ADJ', 'amod'), ('prisoners', 'NOUN', 'pobj'), ('were', 'AUX', 'auxpass'), ('taken', 'VERB', 'ROOT'), ('to', 'ADP', 'prep'), ('Crimea', 'PROPN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Officers', 'NOUN', 'nsubj'), ('also', 'ADV', 'advmod'), ('notified', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('employer', 'NOUN', 'dobj'), ('and', 'CCONJ', 'cc'), ('family', 'NOUN', 'conj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('accused', 'VERB', 'pobj'), (',', 'PUNCT', 'punct'), ('causing', 'VERB', 'advcl'), ('serious', 'ADJ', 'amod'), ('damage', 'NOUN', 'dobj'), ('to', 'ADP', 'prep'), ('their', 'PRON', 'poss'), ('reputations', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Enhanced', 'VERB', 'amod'), ('geothermal', 'ADJ', 'amod'), ('systems', 'NOUN', 'nsubjpass'), ('(', 'PUNCT', 'punct'), ('EGS', 'PROPN', 'appos'), (')', 'PUNCT', 'punct'), (',', 'PUNCT', 'punct'), ('a', 'DET', 'det'), ('new', 'ADJ', 'amod'), ('type', 'NOUN', 'appos'), ('of', 'ADP', 'prep'), ('geothermal', 'ADJ', 'amod'), ('power', 'NOUN', 'compound'), ('technologies', 'NOUN', 'pobj'), ('that', 'PRON', 'nsubj'), ('do', 'AUX', 'aux'), ('not', 'PART', 'neg'), ('require', 'VERB', 'relcl'), ('natural', 'ADJ', 'amod'), ('convective', 'ADJ', 'amod'), ('hydrothermal', 'NOUN', 'compound'), ('resources', 'NOUN', 'dobj'), (',', 'PUNCT', 'punct'), ('are', 'AUX', 'auxpass'), ('known', 'VERB', 'ROOT'), ('to', 'PART', 'aux'), ('be', 'AUX', 'auxpass'), ('associated', 'VERB', 'xcomp'), ('with', 'ADP', 'prep'), ('induced', 'ADJ', 'amod'), ('seismicity', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('resulting', 'VERB', 'amod'), ('asymmetrical', 'ADJ', 'amod'), ('lift', 'NOUN', 'nsubj'), ('caused', 'VERB', 'ROOT'), ('an', 'DET', 'det'), ('uncommanded', 'ADJ', 'amod'), ('roll', 'NOUN', 'dobj'), ('to', 'ADP', 'prep'), ('the', 'DET', 'det'), ('left', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Though', 'SCONJ', 'mark'), ('blisters', 'NOUN', 'nsubj'), ('are', 'AUX', 'advcl'), ('the', 'DET', 'det'), ('most', 'ADV', 'advmod'), ('common', 'ADJ', 'amod'), ('skin', 'NOUN', 'compound'), ('manifestations', 'NOUN', 'attr'), ('of', 'ADP', 'prep'), ('PCT', 'PROPN', 'pobj'), (',', 'PUNCT', 'punct'), ('other', 'ADJ', 'amod'), ('skin', 'NOUN', 'compound'), ('manifestations', 'NOUN', 'appos'), ('like', 'ADP', 'prep'), ('hyperpigmentation', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('as', 'SCONJ', 'mark'), ('if', 'SCONJ', 'mark'), ('they', 'PRON', 'nsubj'), ('are', 'AUX', 'aux'), ('getting', 'VERB', 'meta'), ('a', 'DET', 'det'), ('tan', 'NOUN', 'dobj'), (')', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('hypertrichosis', 'NOUN', 'conj'), ('(', 'PUNCT', 'punct'), ('mainly', 'ADV', 'advmod'), ('on', 'ADP', 'prep'), ('top', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('cheeks', 'NOUN', 'pobj'), (')', 'PUNCT', 'punct'), ('also', 'ADV', 'advmod'), ('occur', 'VERB', 'ROOT'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('R482X', 'NOUN', 'compound'), ('mutation', 'NOUN', 'nsubj'), ('also', 'ADV', 'advmod'), ('increases', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('rate', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('fast', 'ADJ', 'amod'), ('inactivation', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('channel', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('That', 'PRON', 'mark'), ('White', 'PROPN', 'nsubjpass'), ('was', 'AUX', 'auxpass'), ('not', 'PART', 'neg'), ('convicted', 'VERB', 'advcl'), ('of', 'ADP', 'prep'), ('first', 'ADJ', 'amod'), ('-', 'PUNCT', 'punct'), ('degree', 'NOUN', 'compound'), ('murder', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('of', 'ADP', 'prep'), ('which', 'PRON', 'pobj'), ('he', 'PRON', 'nsubjpass'), ('was', 'AUX', 'auxpass'), ('originally', 'ADV', 'advmod'), ('charged', 'VERB', 'relcl'), (')', 'PUNCT', 'punct'), ('had', 'AUX', 'aux'), ('so', 'ADV', 'advmod'), ('outraged', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('city', 'NOUN', 'poss'), ("'s", 'PART', 'case'), ('gay', 'ADJ', 'compound'), ('community', 'NOUN', 'dobj'), ('that', 'SCONJ', 'dobj'), ('it', 'PRON', 'nsubj'), ('set', 'VERB', 'ccomp'), ('off', 'ADP', 'prt'), ('the', 'DET', 'det'), ('most', 'ADV', 'advmod'), ('violent', 'ADJ', 'amod'), ('reaction', 'NOUN', 'dobj'), ('by', 'ADP', 'prep'), ('gay', 'ADJ', 'compound'), ('Americans', 'PROPN', 'pobj'), ('since', 'SCONJ', 'prep'), ('the', 'DET', 'det'), ('1969', 'NUM', 'nummod'), ('Stonewall', 'PROPN', 'compound'), ('Riots', 'PROPN', 'pobj'), ('in', 'ADP', 'prep'), ('New', 'PROPN', 'compound'), ('York', 'PROPN', 'compound'), ('City', 'PROPN', 'pobj'), ('(', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubjpass'), ('is', 'AUX', 'auxpass'), ('credited', 'VERB', 'relcl'), ('as', 'ADP', 'prep'), ('the', 'DET', 'det'), ('beginning', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('modern', 'ADJ', 'amod'), ('gay', 'NOUN', 'compound'), ('rights', 'NOUN', 'compound'), ('movement', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('United', 'PROPN', 'compound'), ('States', 'PROPN', 'pobj'), (')', 'PUNCT', 'punct'), ('.', 'PUNCT', 'punct')]
# [('A', 'DET', 'det'), ('result', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('this', 'DET', 'det'), ('rubbing', 'NOUN', 'pobj'), ('is', 'AUX', 'aux'), ('often', 'ADV', 'advmod'), ('swelling', 'VERB', 'ROOT'), (',', 'PUNCT', 'punct'), ('inflammation', 'NOUN', 'dobj'), ('or', 'CCONJ', 'cc'), ('other', 'ADJ', 'amod'), ('painful', 'ADJ', 'amod'), ('symptoms', 'NOUN', 'conj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('loss', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('GABA', 'PROPN', 'npadvmod'), ('-', 'PUNCT', 'punct'), ('mediated', 'VERB', 'amod'), ('inhibitory', 'ADJ', 'amod'), ('interneurons', 'NOUN', 'pobj'), ('may', 'AUX', 'aux'), ('increase', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('hyperexcitability', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('neurons', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('hippocampus', 'NOUN', 'pobj'), ('leading', 'VERB', 'acl'), ('to', 'ADP', 'prep'), ('recurrent', 'ADJ', 'amod'), ('seizures', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Reactive', 'NOUN', 'compound'), ('armor', 'NOUN', 'nsubj'), ('attempts', 'VERB', 'ROOT'), ('to', 'PART', 'aux'), ('defeat', 'VERB', 'xcomp'), ('this', 'PRON', 'dobj'), ('with', 'ADP', 'prep'), ('an', 'DET', 'det'), ('outward', 'ADV', 'advmod'), ('directed', 'VERB', 'amod'), ('explosion', 'NOUN', 'pobj'), ('under', 'ADP', 'prep'), ('the', 'DET', 'det'), ('impact', 'NOUN', 'compound'), ('point', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('causing', 'VERB', 'advcl'), ('the', 'DET', 'det'), ('jet', 'NOUN', 'nsubj'), ('to', 'PART', 'aux'), ('deform', 'VERB', 'ccomp'), ('and', 'CCONJ', 'cc'), ('so', 'ADV', 'advmod'), ('greatly', 'ADV', 'advmod'), ('reducing', 'VERB', 'conj'), ('penetrating', 'VERB', 'amod'), ('power', 'NOUN', 'dobj'), ('.', 'PUNCT', 'punct')]
# [('In', 'ADP', 'prep'), ('dental', 'ADJ', 'amod'), ('enamel', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('fluorosis', 'NOUN', 'nsubj'), ('causes', 'VERB', 'ROOT'), ('subsurface', 'ADJ', 'compound'), ('porosity', 'NOUN', 'dobj'), ('or', 'CCONJ', 'cc'), ('hypomineralizations', 'NOUN', 'conj'), (',', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubj'), ('extend', 'VERB', 'relcl'), ('toward', 'ADP', 'prep'), ('the', 'DET', 'det'), ('dentinal', 'ADJ', 'amod'), ('-', 'PUNCT', 'punct'), ('enamel', 'NOUN', 'compound'), ('junction', 'NOUN', 'pobj'), ('as', 'ADP', 'prep'), ('severity', 'NOUN', 'compound'), ('increases', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('This', 'DET', 'det'), ('phase', 'NOUN', 'nsubj'), ('can', 'AUX', 'aux'), ('either', 'CCONJ', 'preconj'), ('subside', 'VERB', 'ROOT'), ('or', 'CCONJ', 'cc'), ('progress', 'VERB', 'conj'), ('into', 'ADP', 'prep'), ('a', 'DET', 'det'), ('"', 'PUNCT', 'punct'), ('late', 'ADJ', 'amod'), ('-', 'PUNCT', 'punct'), ('phase', 'NOUN', 'compound'), ('reaction', 'NOUN', 'pobj'), ('"', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubj'), ('can', 'AUX', 'aux'), ('substantially', 'ADV', 'advmod'), ('prolong', 'VERB', 'relcl'), ('the', 'DET', 'det'), ('symptoms', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('a', 'DET', 'det'), ('response', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('result', 'VERB', 'conj'), ('in', 'ADP', 'prep'), ('more', 'ADJ', 'amod'), ('tissue', 'NOUN', 'compound'), ('damage', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Certain', 'ADJ', 'amod'), ('mutations', 'NOUN', 'nsubj'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('HFE', 'PROPN', 'compound'), ('gene', 'NOUN', 'pobj'), ('cause', 'VERB', 'ROOT'), ('hemochromatosis', 'NOUN', 'dobj'), ('(', 'PUNCT', 'punct'), ('an', 'DET', 'det'), ('iron', 'NOUN', 'compound'), ('overload', 'NOUN', 'compound'), ('disorder', 'NOUN', 'appos'), (')', 'PUNCT', 'punct'), ('.', 'PUNCT', 'punct')]
# [('People', 'NOUN', 'nsubj'), ('who', 'PRON', 'nsubj'), ('drink', 'VERB', 'relcl'), ('large', 'ADJ', 'amod'), ('amounts', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('alcohol', 'NOUN', 'pobj'), ('have', 'VERB', 'ROOT'), ('a', 'DET', 'det'), ('good', 'ADJ', 'amod'), ('chance', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('becoming', 'VERB', 'pcomp'), ('malnourished', 'ADJ', 'acomp'), ('or', 'CCONJ', 'cc'), ('losing', 'VERB', 'conj'), ('an', 'DET', 'det'), ('unhealthy', 'ADJ', 'amod'), ('amount', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('weight', 'NOUN', 'pobj'), ('because', 'SCONJ', 'prep'), ('of', 'ADP', 'pcomp'), ('the', 'DET', 'det'), ('absorption', 'NOUN', 'pobj'), ('blocking', 'VERB', 'acl'), ('qualities', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('alcohol', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('One', 'NUM', 'nummod'), ('factor', 'NOUN', 'ROOT'), ('being', 'AUX', 'acl'), ('the', 'DET', 'det'), ('positive', 'ADJ', 'amod'), ('correlation', 'NOUN', 'attr'), ('between', 'ADP', 'prep'), ('higher', 'ADJ', 'amod'), ('intensity', 'NOUN', 'compound'), ('resistance', 'NOUN', 'compound'), ('training', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('greater', 'ADJ', 'amod'), ('improvements', 'NOUN', 'conj'), ('in', 'ADP', 'prep'), ('muscle', 'NOUN', 'compound'), ('strength', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('By', 'ADP', 'prep'), ('far', 'ADV', 'pcomp'), ('the', 'DET', 'det'), ('most', 'ADV', 'advmod'), ('common', 'ADJ', 'amod'), ('cause', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('mixed', 'ADJ', 'amod'), ('-', 'PUNCT', 'punct'), ('field', 'NOUN', 'compound'), ('agglutination', 'NOUN', 'pobj'), ('is', 'AUX', 'ROOT'), ('false', 'ADJ', 'amod'), ('chimerism', 'NOUN', 'attr'), ('.', 'PUNCT', 'punct')]
# [('Individual', 'ADJ', 'amod'), ('susceptibility', 'NOUN', 'nsubjpass'), ('to', 'ADP', 'prep'), ('fluorosis', 'NOUN', 'pobj'), ('is', 'AUX', 'auxpass'), ('also', 'ADV', 'advmod'), ('influenced', 'VERB', 'ROOT'), ('by', 'ADP', 'agent'), ('genetic', 'ADJ', 'amod'), ('factors', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Although', 'SCONJ', 'mark'), ('simple', 'ADJ', 'amod'), ('skin', 'NOUN', 'compound'), ('exposure', 'NOUN', 'nsubj'), ('is', 'AUX', 'advcl'), ('most', 'ADV', 'advmod'), ('common', 'ADJ', 'acomp'), (',', 'PUNCT', 'punct'), ('ingestion', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('urushiol', 'NOUN', 'pobj'), ('can', 'AUX', 'aux'), ('lead', 'VERB', 'ROOT'), ('to', 'ADP', 'prep'), ('serious', 'ADJ', 'amod'), (',', 'PUNCT', 'punct'), ('systemic', 'ADJ', 'amod'), ('reactions', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('To', 'PART', 'aux'), ('limit', 'VERB', 'advcl'), ('the', 'DET', 'det'), ('anxiety', 'NOUN', 'dobj'), ('due', 'ADP', 'prep'), ('to', 'ADP', 'pcomp'), ('these', 'DET', 'det'), ('symptoms', 'NOUN', 'pobj'), ('you', 'PRON', 'nsubj'), ('can', 'AUX', 'aux'), ('consult', 'VERB', 'ROOT'), ('a', 'DET', 'det'), ('health', 'NOUN', 'compound'), ('professional', 'ADJ', 'dobj'), ('or', 'CCONJ', 'cc'), ('a', 'DET', 'det'), ('psychologist', 'NOUN', 'conj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('first', 'ADJ', 'amod'), ('case', 'NOUN', 'nsubjpass'), ('of', 'ADP', 'prep'), ('hyperinsulinism', 'NOUN', 'pobj'), ('due', 'ADP', 'prep'), ('to', 'ADP', 'pcomp'), ('a', 'DET', 'det'), ('tumor', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('this', 'DET', 'det'), ('type', 'NOUN', 'pobj'), ('was', 'AUX', 'auxpass'), ('reported', 'VERB', 'ROOT'), ('in', 'ADP', 'prep'), ('1927', 'NUM', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('About', 'ADV', 'advmod'), ('20', 'NUM', 'nummod'), ('%', 'NOUN', 'nsubjpass'), ('are', 'AUX', 'auxpass'), ('affected', 'VERB', 'ROOT'), ('by', 'ADP', 'agent'), ('symptomatic', 'ADJ', 'amod'), ('digestive', 'ADJ', 'amod'), ('tract', 'NOUN', 'compound'), ('lesions', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('although', 'SCONJ', 'mark'), ('a', 'DET', 'det'), ('higher', 'ADJ', 'amod'), ('percentage', 'NOUN', 'nsubj'), ('have', 'VERB', 'advcl'), ('lesions', 'NOUN', 'dobj'), ('that', 'PRON', 'nsubj'), ('do', 'AUX', 'aux'), ('not', 'PART', 'neg'), ('cause', 'VERB', 'relcl'), ('symptoms', 'NOUN', 'dobj'), ('.', 'PUNCT', 'punct')]
# [('According', 'VERB', 'prep'), ('to', 'ADP', 'prep'), ('a', 'DET', 'det'), ('third', 'ADJ', 'amod'), ('explanation', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('shared', 'VERB', 'amod'), ('stereotypes', 'NOUN', 'nsubjpass'), ('are', 'AUX', 'auxpass'), ('neither', 'PRON', 'neg'), ('caused', 'VERB', 'ROOT'), ('by', 'ADP', 'agent'), ('the', 'DET', 'det'), ('coincidence', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('common', 'ADJ', 'amod'), ('stimuli', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('nor', 'CCONJ', 'cc'), ('by', 'ADP', 'conj'), ('socialisation', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Those', 'DET', 'det'), ('circumstances', 'NOUN', 'nsubj'), ('led', 'VERB', 'ROOT'), ('to', 'ADP', 'prep'), ('an', 'DET', 'det'), ('impact', 'NOUN', 'pobj'), ('on', 'ADP', 'prep'), ('a', 'DET', 'det'), ('terrain', 'NOUN', 'compound'), ('obstacle', 'NOUN', 'pobj'), ('resulting', 'VERB', 'acl'), ('in', 'ADP', 'prep'), ('separation', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('a', 'DET', 'det'), ('part', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('left', 'ADJ', 'amod'), ('wing', 'NOUN', 'pobj'), ('with', 'ADP', 'prep'), ('aileron', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('consequently', 'ADV', 'advmod'), ('to', 'ADP', 'conj'), ('the', 'DET', 'det'), ('loss', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('aircraft', 'NOUN', 'compound'), ('control', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('eventual', 'ADJ', 'amod'), ('ground', 'NOUN', 'compound'), ('impact', 'NOUN', 'conj'), ('"', 'PUNCT', 'punct'), ('Circumstances', 'NOUN', 'pobj'), ('contributing', 'VERB', 'acl'), ('to', 'ADP', 'prep'), ('the', 'DET', 'det'), ('accident', 'NOUN', 'pobj'), (':', 'PUNCT', 'punct'), ('Failure', 'NOUN', 'appos'), ('to', 'PART', 'aux'), ('monitor', 'VERB', 'acl'), ('altitude', 'NOUN', 'dobj'), ('by', 'ADP', 'prep'), ('means', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('a', 'DET', 'det'), ('pressure', 'NOUN', 'compound'), ('altimeter', 'NOUN', 'pobj'), ('during', 'ADP', 'prep'), ('a', 'DET', 'det'), ('non', 'ADJ', 'amod'), ('-', 'PUNCT', 'punct'), ('precision', 'ADJ', 'compound'), ('approach', 'NOUN', 'pobj'), (';', 'PUNCT', 'punct'), ('failure', 'NOUN', 'conj'), ('by', 'ADP', 'prep'), ('the', 'DET', 'det'), ('crew', 'NOUN', 'pobj'), ('to', 'PART', 'aux'), ('respond', 'VERB', 'acl'), ('to', 'ADP', 'prep'), ('the', 'DET', 'det'), ('PULL', 'PROPN', 'amod'), ('UP', 'NOUN', 'prt'), ('warning', 'NOUN', 'pobj'), ('generated', 'VERB', 'acl'), ('by', 'ADP', 'agent'), ('the', 'DET', 'det'), ('TAWS', 'PROPN', 'pobj'), (';', 'PUNCT', 'punct'), ('attempt', 'VERB', 'conj'), ('to', 'PART', 'aux'), ('execute', 'VERB', 'xcomp'), ('the', 'DET', 'det'), ('go', 'VERB', 'nmod'), ('-', 'PUNCT', 'punct'), ('around', 'ADP', 'prt'), ('maneuver', 'NOUN', 'dobj'), ('under', 'ADP', 'prep'), ('the', 'DET', 'det'), ('control', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('ABSU', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('automatic', 'ADJ', 'amod'), ('go', 'VERB', 'compound'), ('-', 'PUNCT', 'punct'), ('around', 'ADP', 'prt'), (')', 'PUNCT', 'punct'), (';', 'PUNCT', 'punct'), ('Approach', 'PROPN', 'compound'), ('Control', 'PROPN', 'npadvmod'), ('confirming', 'VERB', 'acl'), ('to', 'ADP', 'prep'), ('the', 'DET', 'det'), ('crew', 'NOUN', 'pobj'), ('the', 'DET', 'det'), ('correct', 'ADJ', 'amod'), ('position', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('airplane', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('relation', 'NOUN', 'pobj'), ('to', 'ADP', 'prep'), ('the', 'DET', 'det'), ('RWY', 'PROPN', 'compound'), ('threshold', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('glide', 'NOUN', 'compound'), ('slope', 'NOUN', 'appos'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('course', 'NOUN', 'conj'), ('which', 'PRON', 'nsubj'), ('might', 'AUX', 'aux'), ('have', 'AUX', 'aux'), ('affirmed', 'VERB', 'relcl'), ('the', 'DET', 'det'), ('crew', 'NOUN', 'poss'), ("'s", 'PART', 'case'), ('belief', 'NOUN', 'dobj'), ('that', 'SCONJ', 'mark'), ('the', 'DET', 'det'), ('approach', 'NOUN', 'nsubj'), ('was', 'AUX', 'aux'), ('proceeding', 'VERB', 'acl'), ('correctly', 'ADV', 'advmod'), ('although', 'SCONJ', 'mark'), ('the', 'DET', 'det'), ('airplane', 'NOUN', 'nsubj'), ('was', 'AUX', 'advcl'), ('actually', 'ADV', 'advmod'), ('outside', 'ADP', 'prep'), ('the', 'DET', 'det'), ('permissible', 'ADJ', 'amod'), ('deviation', 'NOUN', 'compound'), ('margin', 'NOUN', 'pobj'), (';', 'PUNCT', 'punct'), ('failure', 'NOUN', 'appos'), ('by', 'ADP', 'prep'), ('LZC', 'PROPN', 'pobj'), ('to', 'PART', 'aux'), ('inform', 'VERB', 'acl'), ('the', 'DET', 'det'), ('crew', 'NOUN', 'dobj'), ('ab ...
# [('Unlike', 'ADP', 'prep'), ('gamma', 'NOUN', 'compound'), ('rays', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('beta', 'NOUN', 'compound'), ('emissions', 'NOUN', 'nsubjpass'), ('are', 'AUX', 'auxpass'), ('stopped', 'VERB', 'ROOT'), ('much', 'ADV', 'advmod'), ('more', 'ADV', 'advmod'), ('effectively', 'ADV', 'advmod'), ('by', 'ADP', 'agent'), ('materials', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('therefore', 'ADV', 'advmod'), ('deposit', 'VERB', 'conj'), ('all', 'DET', 'predet'), ('their', 'PRON', 'poss'), ('energy', 'NOUN', 'dobj'), ('in', 'ADP', 'prep'), ('only', 'ADV', 'advmod'), ('a', 'DET', 'det'), ('shallow', 'ADJ', 'amod'), ('layer', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('tissue', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('causing', 'VERB', 'advcl'), ('more', 'ADV', 'advmod'), ('intense', 'ADJ', 'amod'), ('but', 'CCONJ', 'cc'), ('more', 'ADV', 'advmod'), ('localized', 'VERB', 'amod'), ('damage', 'NOUN', 'dobj'), ('.', 'PUNCT', 'punct')]
# [('In', 'ADP', 'prep'), ('the', 'DET', 'det'), ('United', 'PROPN', 'compound'), ('States', 'PROPN', 'pobj'), (',', 'PUNCT', 'punct'), ('the', 'DET', 'det'), ('Food', 'PROPN', 'nmod'), ('Allergen', 'PROPN', 'nmod'), ('Labeling', 'PROPN', 'nmod'), ('and', 'CCONJ', 'cc'), ('Consumer', 'PROPN', 'compound'), ('Protection', 'PROPN', 'conj'), ('Act', 'PROPN', 'nsubj'), ('of', 'ADP', 'prep'), ('2004', 'NUM', 'pobj'), ('causes', 'VERB', 'ROOT'), ('people', 'NOUN', 'nsubjpass'), ('to', 'PART', 'aux'), ('be', 'AUX', 'auxpass'), ('reminded', 'VERB', 'ccomp'), ('of', 'ADP', 'prep'), ('allergy', 'NOUN', 'compound'), ('problems', 'NOUN', 'pobj'), ('every', 'DET', 'det'), ('time', 'NOUN', 'npadvmod'), ('they', 'PRON', 'nsubj'), ('handle', 'VERB', 'relcl'), ('a', 'DET', 'det'), ('food', 'NOUN', 'compound'), ('package', 'NOUN', 'dobj'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('restaurants', 'NOUN', 'nsubj'), ('have', 'AUX', 'aux'), ('added', 'VERB', 'conj'), ('allergen', 'NOUN', 'compound'), ('warnings', 'NOUN', 'dobj'), ('to', 'PART', 'aux'), ('menus', 'VERB', 'advcl'), ('.', 'PUNCT', 'punct')]
# [('Aside', 'ADV', 'advmod'), ('from', 'ADP', 'prep'), ('asymmetric', 'ADJ', 'amod'), ('ptosis', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubj'), ('becomes', 'VERB', 'relcl'), ('worse', 'ADJ', 'acomp'), ('with', 'ADP', 'prep'), ('fatigue', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('sustained', 'VERB', 'ROOT'), ('upgaze', 'ADJ', 'advmod'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('at', 'ADP', 'conj'), ('the', 'DET', 'det'), ('end', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('day', 'NOUN', 'pobj'), (')', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('variable', 'ADJ', 'amod'), ('limitation', 'NOUN', 'conj'), ('of', 'ADP', 'prep'), ('extraocular', 'ADJ', 'amod'), ('muscles', 'NOUN', 'nmod'), ('/', 'SYM', 'punct'), ('diplopia', 'PROPN', 'pobj'), (',', 'PUNCT', 'punct'), ('other', 'ADJ', 'amod'), ('clinical', 'ADJ', 'amod'), ('signs', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('ocular', 'ADJ', 'amod'), ('MG', 'PROPN', 'pobj'), ('include', 'VERB', 'conj'), ('gaze', 'NOUN', 'npadvmod'), ('-', 'PUNCT', 'punct'), ('evoked', 'VERB', 'amod'), ('nystagmus', 'ADJ', 'amod'), ('(', 'PUNCT', 'punct'), ('rapid', 'ADJ', 'amod'), (',', 'PUNCT', 'punct'), ('involuntary', 'ADJ', 'conj'), (',', 'PUNCT', 'punct'), ('oscillatory', 'ADJ', 'amod'), ('motion', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('eyeball', 'NOUN', 'pobj'), (')', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('Cogan', 'PROPN', 'poss'), ('’s', 'PART', 'case'), ('lid', 'NOUN', 'compound'), ('twitch', 'NOUN', 'conj'), ('(', 'PUNCT', 'punct'), ('upper', 'ADJ', 'amod'), ('lid', 'NOUN', 'nsubj'), ('twitch', 'VERB', 'parataxis'), ('present', 'ADJ', 'acomp'), ('when', 'SCONJ', 'advmod'), ('patient', 'ADJ', 'nsubj'), ('looks', 'VERB', 'advcl'), ('straight', 'ADV', 'advmod'), ('ahead', 'ADV', 'advmod'), ('after', 'ADP', 'prep'), ('looking', 'VERB', 'pcomp'), ('down', 'ADP', 'prt'), ('for', 'ADP', 'prep'), ('10', 'NUM', 'nummod'), ('–', 'SYM', 'punct'), ('15', 'NUM', 'nummod'), ('seconds', 'NOUN', 'pobj'), (')', 'PUNCT', 'punct'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('swelling', 'NOUN', 'nsubj'), ('is', 'AUX', 'ROOT'), ('capable', 'ADJ', 'acomp'), ('of', 'ADP', 'prep'), ('blocking', 'VERB', 'pcomp'), ('nearby', 'ADJ', 'amod'), ('biliary', 'ADJ', 'amod'), ('ducts', 'NOUN', 'dobj'), (',', 'PUNCT', 'punct'), ('leading', 'VERB', 'advcl'), ('to', 'PART', 'aux'), ('diffuse', 'VERB', 'advcl'), ('cholestasis', 'NOUN', 'dobj'), ('.', 'PUNCT', 'punct')]
# [('Medical', 'ADJ', 'amod'), ('problems', 'NOUN', 'nsubj'), ('can', 'AUX', 'aux'), ('result', 'VERB', 'ROOT'), ('in', 'ADP', 'prep'), ('interventions', 'NOUN', 'pobj'), ('that', 'PRON', 'nsubj'), ('can', 'AUX', 'aux'), ('be', 'AUX', 'relcl'), ('frightening', 'ADJ', 'acomp'), ('.', 'PUNCT', 'punct')]
# ...
# [('Racial', 'ADJ', 'amod'), ('or', 'CCONJ', 'cc'), ('ethnic', 'ADJ', 'conj'), ('differentiation', 'NOUN', 'nsubjpass'), ('has', 'AUX', 'aux'), ('been', 'AUX', 'auxpass'), ('well', 'ADV', 'advmod'), ('acknowledged', 'VERB', 'ROOT'), ('as', 'ADP', 'prep'), ('a', 'DET', 'det'), ('means', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('depriving', 'VERB', 'pcomp'), ('certain', 'ADJ', 'amod'), ('racial', 'ADJ', 'amod'), ('or', 'CCONJ', 'cc'), ('ethnic', 'ADJ', 'conj'), ('groups', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('basic', 'ADJ', 'amod'), ('human', 'ADJ', 'amod'), ('rights', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('or', 'CCONJ', 'cc'), ('from', 'ADP', 'prep'), ('receiving', 'VERB', 'pcomp'), ('the', 'DET', 'det'), ('same', 'ADJ', 'amod'), ('quality', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('resources', 'NOUN', 'pobj'), ('as', 'ADP', 'prep'), ('others', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Gout', 'PROPN', 'nsubj'), ('is', 'AUX', 'ROOT'), ('due', 'ADJ', 'acomp'), ('to', 'ADP', 'prep'), ('persistently', 'ADV', 'advmod'), ('elevated', 'VERB', 'amod'), ('levels', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('uric', 'ADJ', 'amod'), ('acid', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('blood', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('It', 'PRON', 'nsubjpass'), ('is', 'AUX', 'auxpass'), ('usually', 'ADV', 'advmod'), ('found', 'VERB', 'ROOT'), ('in', 'ADP', 'prep'), ('association', 'NOUN', 'pobj'), ('with', 'ADP', 'prep'), ('fatty', 'PROPN', 'compound'), ('liver', 'PROPN', 'pobj'), (',', 'PUNCT', 'punct'), ('an', 'DET', 'det'), ('early', 'ADJ', 'amod'), ('stage', 'NOUN', 'appos'), ('of', 'ADP', 'prep'), ('alcoholic', 'ADJ', 'amod'), ('liver', 'NOUN', 'compound'), ('disease', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('may', 'AUX', 'aux'), ('contribute', 'VERB', 'conj'), ('to', 'ADP', 'prep'), ('the', 'DET', 'det'), ('progression', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('fibrosis', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('leading', 'VERB', 'advcl'), ('to', 'PART', 'aux'), ('cirrhosis', 'VERB', 'xcomp'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('risk', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('pancreatic', 'ADJ', 'amod'), ('cancer', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('individuals', 'NOUN', 'pobj'), ('with', 'ADP', 'prep'), ('familial', 'ADJ', 'amod'), ('pancreatitis', 'NOUN', 'pobj'), ('is', 'AUX', 'ROOT'), ('particularly', 'ADV', 'advmod'), ('high', 'ADJ', 'acomp'), ('.', 'PUNCT', 'punct')]
# [('Ulcerations', 'NOUN', 'nsubj'), ('are', 'AUX', 'ROOT'), ('also', 'ADV', 'advmod'), ('at', 'ADP', 'prep'), ('risk', 'NOUN', 'pobj'), ('for', 'ADP', 'prep'), ('bleeding', 'VERB', 'pobj'), (',', 'PUNCT', 'punct'), ('particularly', 'ADV', 'advmod'), ('deep', 'ADJ', 'amod'), ('lesions', 'NOUN', 'dobj'), ('or', 'CCONJ', 'cc'), ('in', 'ADP', 'conj'), ('areas', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('friction', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Erythema', 'PROPN', 'nsubj'), ('may', 'AUX', 'aux'), ('occur', 'VERB', 'ROOT'), ('at', 'ADP', 'prep'), ('a', 'DET', 'det'), ('dose', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('2', 'NUM', 'nummod'), ('Gy', 'PROPN', 'compound'), ('radiation', 'NOUN', 'pobj'), ('or', 'CCONJ', 'cc'), ('greater', 'ADJ', 'conj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('relative', 'ADJ', 'amod'), ('quiet', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('Tatar', 'PROPN', 'compound'), ('attacks', 'NOUN', 'pobj'), ('on', 'ADP', 'prep'), ('Russia', 'PROPN', 'pobj'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('late', 'ADJ', 'amod'), ('30s', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('early', 'ADJ', 'amod'), ('40s', 'NOUN', 'conj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('17th', 'ADJ', 'amod'), ('century', 'NOUN', 'pobj'), ('is', 'AUX', 'ROOT'), ('undoubtedly', 'ADV', 'advmod'), ('due', 'ADJ', 'acomp'), ('to', 'ADP', 'pcomp'), ('the', 'DET', 'det'), ('occupation', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('Azov', 'PROPN', 'pobj'), ('by', 'ADP', 'prep'), ('the', 'DET', 'det'), ('Don', 'PROPN', 'compound'), ('Cossacks', 'PROPN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('main', 'ADJ', 'amod'), ('symptom', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('benign', 'ADJ', 'amod'), ('fasciculation', 'NOUN', 'compound'), ('syndrome', 'NOUN', 'pobj'), ('is', 'AUX', 'ROOT'), ('focal', 'ADJ', 'amod'), ('or', 'CCONJ', 'cc'), ('widespread', 'ADJ', 'conj'), ('involuntary', 'ADJ', 'amod'), ('muscle', 'NOUN', 'compound'), ('activity', 'NOUN', 'attr'), ('(', 'PUNCT', 'punct'), ('twitching', 'NOUN', 'appos'), (')', 'PUNCT', 'punct'), (',', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubj'), ('can', 'AUX', 'aux'), ('occur', 'VERB', 'relcl'), ('at', 'ADP', 'prep'), ('random', 'ADJ', 'amod'), ('or', 'CCONJ', 'cc'), ('specific', 'ADJ', 'conj'), ('times', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('or', 'CCONJ', 'cc'), ('places', 'NOUN', 'conj'), (')', 'PUNCT', 'punct'), ('.', 'PUNCT', 'punct')]
# [('Another', 'DET', 'det'), ('possible', 'ADJ', 'amod'), ('area', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('damage', 'NOUN', 'pobj'), ('leading', 'VERB', 'acl'), ('to', 'ADP', 'prep'), ('IA', 'PROPN', 'pobj'), ('is', 'AUX', 'ROOT'), ('the', 'DET', 'det'), ('submarginal', 'ADJ', 'amod'), ('gyrus', 'NOUN', 'attr'), (',', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubjpass'), ('is', 'AUX', 'auxpass'), ('located', 'VERB', 'relcl'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('parietal', 'ADJ', 'amod'), ('lobe', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('brain', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('This', 'DET', 'det'), ('process', 'NOUN', 'nsubj'), ('takes', 'VERB', 'ROOT'), ('place', 'NOUN', 'dobj'), ('when', 'SCONJ', 'advmod'), ('the', 'DET', 'det'), ('body', 'NOUN', 'nsubj'), ('releases', 'VERB', 'advcl'), ('adrenaline', 'NOUN', 'dobj'), ('into', 'ADP', 'prep'), ('the', 'DET', 'det'), ('blood', 'NOUN', 'compound'), ('stream', 'NOUN', 'pobj'), ('causing', 'VERB', 'advcl'), ('a', 'DET', 'det'), ('chain', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('reactions', 'NOUN', 'pobj'), ('to', 'PART', 'aux'), ('occur', 'VERB', 'relcl'), ('.', 'PUNCT', 'punct')]
# [('When', 'SCONJ', 'advmod'), ('a', 'DET', 'det'), ('student', 'NOUN', 'nsubjpass'), ('is', 'AUX', 'auxpass'), ('stressed', 'VERB', 'advcl'), (',', 'PUNCT', 'punct'), ('the', 'DET', 'det'), ('stress', 'NOUN', 'compound'), ('hormone', 'NOUN', 'compound'), ('cortisol', 'NOUN', 'nsubjpass'), ('is', 'AUX', 'auxpass'), ('released', 'VERB', 'ROOT'), (',', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubj'), ('causes', 'VERB', 'advcl'), ('some', 'DET', 'det'), ('individuals', 'NOUN', 'nsubj'), ('to', 'PART', 'aux'), ('excessively', 'ADV', 'advmod'), ('eat', 'VERB', 'ccomp'), ('.', 'PUNCT', 'punct')]
# [('Prenatal', 'ADJ', 'amod'), ('testing', 'NOUN', 'nsubj'), ('for', 'ADP', 'prep'), ('pregnancies', 'NOUN', 'pobj'), ('at', 'ADP', 'prep'), ('increased', 'VERB', 'amod'), ('risk', 'NOUN', 'pobj'), ('is', 'AUX', 'ROOT'), ('possible', 'ADJ', 'acomp'), ('if', 'SCONJ', 'mark'), ('the', 'DET', 'det'), ('disease', 'NOUN', 'npadvmod'), ('-', 'PUNCT', 'punct'), ('causing', 'VERB', 'amod'), ('mutation', 'NOUN', 'nsubjpass'), ('has', 'AUX', 'aux'), ('been', 'AUX', 'auxpass'), ('identified', 'VERB', 'advcl'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('family', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Although', 'SCONJ', 'mark'), ('the', 'DET', 'det'), ('theory', 'NOUN', 'nsubj'), ('is', 'AUX', 'advcl'), ('controversial', 'ADJ', 'acomp'), (',', 'PUNCT', 'punct'), ('there', 'PRON', 'expl'), ('is', 'VERB', 'ROOT'), ('a', 'DET', 'det'), ('link', 'NOUN', 'attr'), ('between', 'ADP', 'prep'), ('febrile', 'ADJ', 'amod'), ('seizures', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('seizures', 'NOUN', 'appos'), ('coinciding', 'VERB', 'acl'), ('with', 'ADP', 'prep'), ('episodes', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('fever', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('young', 'ADJ', 'amod'), ('children', 'NOUN', 'pobj'), (')', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('subsequent', 'ADJ', 'amod'), ('temporal', 'ADJ', 'amod'), ('lobe', 'PROPN', 'compound'), ('epilepsy', 'PROPN', 'conj'), (',', 'PUNCT', 'punct'), ('at', 'ADP', 'advmod'), ('least', 'ADJ', 'advmod'), ('epidemiologically', 'ADV', 'advmod'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('other', 'ADJ', 'amod'), ('factor', 'NOUN', 'ROOT'), ('being', 'AUX', 'acl'), ('a', 'DET', 'det'), ('direct', 'ADJ', 'amod'), ('relationship', 'NOUN', 'attr'), ('between', 'ADP', 'prep'), ('increased', 'VERB', 'amod'), ('resistance', 'NOUN', 'compound'), ('training', 'NOUN', 'compound'), ('volume', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('which', 'PRON', 'nsubj'), ('is', 'AUX', 'relcl'), ('the', 'DET', 'det'), ('total', 'ADJ', 'amod'), ('number', 'NOUN', 'attr'), ('of', 'ADP', 'prep'), ('exercise', 'NOUN', 'compound'), ('sets', 'NOUN', 'pobj'), ('performed', 'VERB', 'acl'), ('in', 'ADP', 'prep'), ('a', 'DET', 'det'), ('session', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('improvements', 'NOUN', 'conj'), ('in', 'ADP', 'prep'), ('lean', 'ADJ', 'amod'), ('body', 'NOUN', 'compound'), ('mass', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('When', 'SCONJ', 'advmod'), ('we', 'PRON', 'nsubj'), ('see', 'VERB', 'advcl'), ('another', 'DET', 'det'), ('person', 'NOUN', 'nsubj'), ('suffering', 'VERB', 'ccomp'), (',', 'PUNCT', 'punct'), ('it', 'PRON', 'nsubj'), ('can', 'AUX', 'aux'), ('also', 'ADV', 'advmod'), ('cause', 'VERB', 'ROOT'), ('us', 'PRON', 'compound'), ('pain', 'NOUN', 'ccomp'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('report', 'NOUN', 'nsubj'), ('noted', 'VERB', 'ROOT'), ('that', 'SCONJ', 'mark'), ('hydraulic', 'ADJ', 'compound'), ('fracturing', 'NOUN', 'nsubj'), ('has', 'VERB', 'ccomp'), ('a', 'DET', 'det'), ('low', 'ADJ', 'amod'), ('risk', 'NOUN', 'dobj'), ('for', 'ADP', 'prep'), ('inducing', 'VERB', 'pcomp'), ('earthquakes', 'NOUN', 'dobj'), ('that', 'PRON', 'nsubjpass'), ('can', 'AUX', 'aux'), ('be', 'AUX', 'auxpass'), ('felt', 'VERB', 'relcl'), ('by', 'ADP', 'agent'), ('people', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('but', 'CCONJ', 'cc'), ('underground', 'ADJ', 'amod'), ('injection', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('wastewater', 'NOUN', 'pobj'), ('produced', 'VERB', 'acl'), ('by', 'ADP', 'agent'), ('hydraulic', 'ADJ', 'amod'), ('fracturing', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('other', 'ADJ', 'amod'), ('energy', 'NOUN', 'compound'), ('technologies', 'NOUN', 'conj'), ('has', 'VERB', 'conj'), ('a', 'DET', 'det'), ('higher', 'ADJ', 'amod'), ('risk', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('causing', 'VERB', 'pcomp'), ('such', 'ADJ', 'amod'), ('earthquakes', 'NOUN', 'dobj'), ('.', 'PUNCT', 'punct')]
# [('Loneliness', 'NOUN', 'nsubj'), ('and', 'CCONJ', 'cc'), ('depression', 'NOUN', 'conj'), ('can', 'AUX', 'aux'), ('arise', 'VERB', 'ROOT'), ('as', 'ADP', 'prep'), ('a', 'DET', 'det'), ('result', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('isolation', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('from', 'ADP', 'prep'), ('the', 'DET', 'det'), ('inability', 'NOUN', 'pobj'), ('to', 'PART', 'aux'), ('communicate', 'VERB', 'acl'), ('with', 'ADP', 'prep'), ('friends', 'NOUN', 'pobj'), ('and', 'CCONJ', 'cc'), ('loved', 'VERB', 'amod'), ('ones', 'NOUN', 'conj'), (')', 'PUNCT', 'punct'), ('and', 'CCONJ', 'cc'), ('difficulty', 'NOUN', 'conj'), ('in', 'ADP', 'prep'), ('accepting', 'VERB', 'pcomp'), ('their', 'PRON', 'poss'), ('disability', 'NOUN', 'dobj'), ('.', 'PUNCT', 'punct')]
# [('Mining', 'NOUN', 'nsubj'), ('leaves', 'VERB', 'ROOT'), ('voids', 'NOUN', 'dobj'), ('that', 'PRON', 'nsubj'), ('generally', 'ADV', 'advmod'), ('alter', 'VERB', 'relcl'), ('the', 'DET', 'det'), ('balance', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('forces', 'NOUN', 'pobj'), ('in', 'ADP', 'prep'), ('the', 'DET', 'det'), ('rock', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('many', 'ADJ', 'amod'), ('times', 'NOUN', 'npadvmod'), ('causing', 'VERB', 'advcl'), ('rock', 'NOUN', 'compound'), ('bursts', 'NOUN', 'dobj'), ('.', 'PUNCT', 'punct')]
# [('The', 'DET', 'det'), ('presence', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('combined', 'VERB', 'amod'), ('injury', 'NOUN', 'pobj'), ('(', 'PUNCT', 'punct'), ('exposure', 'NOUN', 'appos'), ('to', 'ADP', 'prep'), ('radiation', 'NOUN', 'pobj'), ('plus', 'CCONJ', 'cc'), ('trauma', 'NOUN', 'conj'), ('or', 'CCONJ', 'cc'), ('radiation', 'NOUN', 'compound'), ('burn', 'NOUN', 'conj'), (')', 'PUNCT', 'punct'), ('increases', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('likelihood', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('generalized', 'ADJ', 'amod'), ('sepsis', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Coupled', 'VERB', 'advcl'), ('with', 'ADP', 'prep'), ('a', 'DET', 'det'), ('continuing', 'VERB', 'amod'), ('series', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('political', 'ADJ', 'amod'), ('upheavals', 'NOUN', 'pobj'), ('that', 'PRON', 'nsubj'), ('have', 'AUX', 'aux'), ('led', 'VERB', 'relcl'), ('to', 'ADP', 'prep'), ('an', 'DET', 'det'), ('unending', 'ADJ', 'amod'), ('social', 'ADJ', 'amod'), ('instability', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('Haiti', 'PROPN', 'poss'), ("'s", 'PART', 'case'), ('inefficient', 'ADJ', 'amod'), ('healthcare', 'NOUN', 'compound'), ('framework', 'NOUN', 'nsubj'), ('has', 'AUX', 'aux'), ('crippled', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('nation', 'NOUN', 'poss'), ("'s", 'PART', 'case'), ('ability', 'NOUN', 'dobj'), ('to', 'PART', 'aux'), ('provide', 'VERB', 'acl'), ('good', 'ADJ', 'amod'), ('healthcare', 'NOUN', 'compound'), ('access', 'NOUN', 'dobj'), ('to', 'ADP', 'prep'), ('its', 'PRON', 'poss'), ('people', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('In', 'ADP', 'prep'), ('the', 'DET', 'det'), ('United', 'PROPN', 'compound'), ('States', 'PROPN', 'pobj'), (',', 'PUNCT', 'punct'), ('a', 'DET', 'det'), ('1930', 'NUM', 'nummod'), ('epidemic', 'NOUN', 'nsubj'), ('of', 'ADP', 'prep'), ('silicosis', 'NOUN', 'pobj'), ('due', 'ADP', 'prep'), ('to', 'ADP', 'pcomp'), ('the', 'DET', 'det'), ('construction', 'NOUN', 'pobj'), ('of', 'ADP', 'prep'), ('the', 'DET', 'det'), ('Hawk', 'PROPN', 'poss'), ("'s", 'PART', 'case'), ('Nest', 'PROPN', 'compound'), ('Tunnel', 'PROPN', 'pobj'), ('near', 'ADP', 'prep'), ('Gauley', 'PROPN', 'compound'), ('Bridge', 'PROPN', 'pobj'), (',', 'PUNCT', 'punct'), ('West', 'PROPN', 'compound'), ('Virginia', 'PROPN', 'appos'), ('caused', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('death', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('at', 'ADV', 'advmod'), ('least', 'ADV', 'advmod'), ('400', 'NUM', 'nummod'), ('workers', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')]
# [('Most', 'ADJ', 'amod'), ('anticonvulsants', 'NOUN', 'nsubj'), ('function', 'VERB', 'ROOT'), ('by', 'ADP', 'prep'), ('decreasing', 'VERB', 'pcomp'), ('the', 'DET', 'det'), ('excitation', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('neurons', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('for', 'ADP', 'prep'), ('example', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('by', 'ADP', 'prep'), ('blocking', 'VERB', 'pcomp'), ('fast', 'ADJ', 'amod'), ('or', 'CCONJ', 'cc'), ('slow', 'ADJ', 'conj'), ('sodium', 'NOUN', 'compound'), ('channels', 'NOUN', 'dobj'), ('or', 'CCONJ', 'cc'), ('by', 'ADP', 'conj'), ('modulating', 'VERB', 'pcomp'), ('calcium', 'NOUN', 'compound'), ('channels', 'NOUN', 'dobj'), (';', 'PUNCT', 'punct'), ('or', 'CCONJ', 'cc'), ('by', 'ADP', 'conj'), ('enhancing', 'VERB', 'pcomp'), ('the', 'DET', 'det'), ('inhibition', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('neurons', 'NOUN', 'pobj'), (',', 'PUNCT', 'punct'), ('for', 'ADP', 'prep'), ('example', 'NOUN', 'pobj'), ('by', 'ADP', 'prep'), ('potentiating', 'VERB', 'pcomp'), ('the', 'DET', 'det'), ('effects', 'NOUN', 'dobj'), ('of', 'ADP', 'prep'), ('inhibitory', 'ADJ', 'amod'), ('neurotransmitters', 'NOUN', 'pobj'), ('like', 'ADP', 'prep'), ('GABA', 'PROPN', 'pobj'), ('.', 'PUNCT', 'punct')]

# %%
X = [sent2features(s) for s in sentences]
y_pred = crf.predict(X)
print(y_pred)
flat_y_pred = flatten(y_pred)
# Out:
# [['O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O'], ['B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O'], ['B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O'], ['B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O'], ['B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-EVENT', 'I-EVENT', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O'], ['B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', ' ...

# %%
Path("predictions.txt").write_text("\n".join(map(str, flat_y_pred)));

# %%
# evaluation wie auf tira
# evaluate ist ein package, das ihr installieren müsst, `pip install evaluate`
import evaluate

# speichert die training predictions unter predictions.txt ab
# führt dann diese zelle aus. falls alles funktioniert, sollte es auch auf tira gehen
# auf tira aber natürlich den test datensatz verwenden!!!!

loaded_predictions = list(sentence.split("\n") for sentence in Path("predictions.txt").read_text().split("\n\n"))
print(loaded_predictions)

evaluator = evaluate.load("fschlatt/ner_eval")
evaluator.compute(predictions=loaded_predictions, references=labels)
# Out:
# [["['O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']", "['B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O']", "['O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']", "['B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O']", "['O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O']", "['O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O']", "['B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O']", "['B-EVENT', 'I-EVENT', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O']", "['B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']", "['O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'B-EVENT', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']", "['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']", "['O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'O']", "['O', 'O', 'O', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ' ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 13
#      10 print(loaded_predictions)
#      12 evaluator = evaluate.load("fschlatt/ner_eval")
# ---> 13 evaluator.compute(predictions=loaded_predictions, references=labels)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/evaluate/module.py:432, in EvaluationModule.compute(self, predictions, references, **kwargs)
#     429 compute_kwargs = {k: kwargs[k] for k in kwargs if k not in self._feature_names()}
#     431 if any(v is not None for v in inputs.values()):
# --> 432     self.add_batch(**inputs)
#     433 self._finalize()
#     435 self.cache_file_name = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/evaluate/module.py:512, in EvaluationModule.add_batch(self, predictions, references, **kwargs)
#     505 else:
#     506     error_msg = (
#     507         f"Predictions and/or references don't match the expected format.\n"
#     508         f"Expected format: {self.selected_feature_format },\n"
#     509         f"Input predictions: {summarize_if_long_list(predictions)},\n"
#     510         f"Input references: {summarize_if_long_list(references)}"
#     511     )
# --> 512 raise ValueError(error_msg) from None
#
# ValueError: Mismatch in the number of predictions (1) and references (468)
